# %%
import datetime
import math
import pandas as pd
import random
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import radar
from faker import Faker
fake = Faker()
import matplotlib.pyplot as plt

# %%
def generateData(n):
    listdata = []
    start = datetime.datetime(2019, 8, 1)
    end = datetime.datetime(2019, 8, 30)
    delta = end - start
    for _ in range(n):
        date = radar.random_datetime(start='2019-08-1',stop='2019-08-30').strftime("%Y-%m-%d")
        price = round(random.uniform(900, 1000), 4)
        listdata.append([date, price])
        df = pd.DataFrame(listdata, columns = ['Date', 'Price'])
        df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
        df = df.groupby(by='Date').mean()
    return df

# %%
df = generateData(50)
df.head(5)
# Out:
#                  Price
# Date
# 2019-08-01  972.629167
# 2019-08-02  949.067500
# 2019-08-03  916.351500
# 2019-08-04  941.148700
# 2019-08-06  942.995833

# %% [markdown]
# # Line Plot

# %%
plt.rcParams['figure.figsize'] = (14, 10)
plt.plot(df)

# %% [markdown]
# # Bar Plot

# %%
import numpy as np
import calendar
import matplotlib.pyplot as plt

# %%
months = list(range(1, 13))
sold_quantity = [round(random.uniform(100, 200)) for x in range(1,13)]

# %%
figure, axis = plt.subplots()

plt.xticks(months, calendar.month_name[1:13], rotation=20)

plot = axis.bar(months, sold_quantity)

plt.show()

# %%
headers_cols = ['age','min_recommended', 'max_recommended','may_be_appropriate_min', 'may_be_appropriate_max',
                'min_not_recommended','max_not_recommended']
sleepDf = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/hands-on-exploratory-data-analysis-with-python/master/Chapter%202/sleep_vs_age.csv')#,names=headers_cols)
sleepDf.head(10)
# Out:
#    Unnamed: 0  age  min_recommended  max_recommended  may_be_appropriate_min  \
# 0           0    0               14               17                      11
# 1           1    1               14               17                      11
# 2           2    2               14               17                      11
# 3           3    3               14               17                      11
# 4           4    4               12               15                      10
# 5           5    5               12               15                      10
# 6           6    6               12               15                      10
# 7           7    7               12               15                      10
# 8           8    8               12               15                      10
# 9           9    9               12               15                      10
#
#    may_be_appropriate_max  min_not_recommended  max_not_recommended
# 0                      13                   11                   19
# 1                      13                   11                   19
# 2                      13                   11                   19
# 3                      13                   11                   19
# 4                      11                   10                   18
# 5                      11                   10                   18
# 6                      11                   10                   18
# 7                      11                   10                   18
# 8                      11                   10                   18
# 9                      11                   10                   18

# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['figure.dpi'] = 150

# %%
sns.set()

df = sns.load_dataset('iris')
df['species'] = df['species'].map({'setosa': 0, "versicolor": 1,"virginica": 2})

plt.scatter(x=df["sepal_length"], y=df["sepal_width"], c = df.species)

plt.xlabel('Septal Length')
plt.ylabel('Petal length')

plt.show()

# %% [markdown]
# Bubble Chart: A bubble plot is a manifestation of the scatter plot where each data point on the graph is
# shown as a bubble. Each bubble can be illustrated with a different color, size, and
# appearance

# %%
plt.scatter(df.petal_length, df.petal_width,
 s=50*df.petal_length*df.petal_width, # Size
 c=df.species, # Color
 alpha=0.3
 )
# Create labels for axises
plt.xlabel('Septal Length')
plt.ylabel('Petal length')
plt.show()

# %% [markdown]
# # Scatter plot using the seaborn

# %%
df = sns.load_dataset('iris')
df['species'] = df['species'].map({'setosa': "setosa", "versicolor": "versicolor","virginica": "virginica"})

sns.scatterplot(x=df["sepal_length"], y=df["sepal_width"], hue=df.species, data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>
